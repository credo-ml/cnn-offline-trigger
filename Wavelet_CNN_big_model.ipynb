# %%
import tensorflow as tf

print(tf.keras.__version__)
# Out:
# 2.5.0

# %%
! git clone https://github.com/credo-ml/cnn-offline-trigger.git
    
! unzip ./cnn-offline-trigger/data-set.zip
! pip install mahotas
# Out:
# Cloning into 'cnn-offline-trigger'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 28 (delta 10), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (28/28), done.
# Archive:  ./cnn-offline-trigger/data-set.zip
#    creating: hit-images-final/
#    creating: hit-images-final/artefacts/
#  extracting: hit-images-final/artefacts/10219929.png
#  extracting: hit-images-final/artefacts/10219931.png
#  extracting: hit-images-final/artefacts/10223942.png
#  extracting: hit-images-final/artefacts/10228003.png
#  extracting: hit-images-final/artefacts/10231268.png
#  extracting: hit-images-final/artefacts/10231560.png
#  extracting: hit-images-final/artefacts/10232861.png
#  extracting: hit-images-final/artefacts/10233802.png
#  extracting: hit-images-final/artefacts/10235049.png
#  extracting: hit-images-final/artefacts/10235948.png
#  extracting: hit-images-final/artefacts/10245995.png
#  extracting: hit-images-final/artefacts/10259097.png
#  extracting: hit-images-final/artefacts/1423633.png
#  extracting: hit-images-final/artefacts/1423831.png
#  extracting: hit-images-final/artefacts/1423932.png
#  extracting: hit-images-final/artefacts/1424898.png
#  extracting: hit-images-final/artefacts/1425966.png
#  extracting: hit-images-final/artefacts/1426183.png
#  extracting: hit-images-final/artefacts/1428338.png
#  extracting: hit-images-final/artefacts/1428689.png
#  extracting: hit-images-final/artefacts/1428995.png
#  extracting: hit-images-final/artefacts/1429042.png
#  extracting: hit-images-final/artefacts/1429130.png
#  extracting: hit-images-final/artefacts/1429361.png
#  extracting: hit-images-final/artefacts/1429363.png
#  extracting: hit-images-final/artefacts/1430355.png
#  extracting: hit-images-final/artefacts/1430365.png
#  extracting: hit-images-final/artefacts/1438462.png
#  extracting: hit-images-final/artefacts/1438662.png
#  extracting: hit-images-final/artefacts/1438698.png
#  extracting: hit-images-final/artefacts/1438699.png
#  extracting: hit-images-final/artefacts/1441422.png
#  extracting: hit-images-final/artefacts/1441431.png
#  extracting: hit-images-final/artefacts/1441840.png
#  extracting: hit-images-final/artefacts/1441841.png
#  extracting: hit-images-final/artefacts/1441842.png
#  extracting: hit-images-final/artefacts/1441843.png
#  extracting: hit-images-final/artefacts/1441844.png
#  extracting: hit-images-final/artefacts/1441845.png
#  extracting: hit-images-final/artefacts/1441846.png
#  extracting: hit-images-final/artefacts/1441847.png
#  extracting: hit-images-final/artefacts/1441848.png
#  extracting: hit-images-final/artefacts/1441849.png
#  extracting: hit-images-final/artefacts/1441850.png
#  extracting: hit-images-final/artefacts/1441851.png
#  extracting: hit-images-final/artefacts/1441852.png
#  extracting: hit-images-final/artefacts/1441853.png
#  extracting: hit-images-final/artefacts/1441855.png
#  extracting: hit-images-final/artefacts/1451756.png
#  extracting: hit-images-final/artefacts/1451757.png
#  extracting: hit-images-final/artefacts/1451758.png
#  extracting: hit-images-final/artefacts/1459424.png
#  extracting: hit-images-final/artefacts/1460111.png
#  extracting: hit-images-final/artefacts/1460112.png
#  extracting: hit-images-final/artefacts/1460113.png
#  extracting: hit-images-final/artefacts/1460114.png
#  extracting: hit-images-final/artefacts/1460116.png
#  extracting: hit-images-final/artefacts/1460117.png
#  extracting: hit-images-final/artefacts/1460146.png
#  extracting: hit-images-final/artefacts/1460155.png
#  extracting: hit-images-final/artefacts/1460156.png
#  extracting: hit-images-final/artefacts/1460388.png
#  extracting: hit-images-final/artefacts/1476574.png
#  extracting: hit-images-final/artefacts/1482480.png
#  extracting: hit-images-final/artefacts/1487780.png
#  extracting: hit-images-final/artefacts/1489155.png
#  extracting: hit-images-final/artefacts/1491263.png
#  extracting: hit-images-final/artefacts/1603819.png
#  extracting: hit-images-final/artefacts/1605975.png
#  extracting: hit-images-final/artefacts/1607611.png
#  extracting: hit-images-final/artefacts/1608634.png
#  extracting: hit-images-final/artefacts/1613649.png
#  extracting: hit-images-final/artefacts/1615987.png
#  extracting: hit-images-final/artefacts/1615990.png
#  extracting: hit-images-final/artefacts/1615991.png
#  extracting: hit-images-final/artefacts/1615992.png
#  extracting: hit-images-final/artefacts/1615993.png
#  extracting: hit-images-final/artefacts/1615994.png
#  extracting: hit-images-final/artefacts/1617864.png
#  extracting: hit-images-final/artefacts/1617919.png
#  extracting: hit-images-final/artefacts/1618681.png
#  extracting: hit-images-final/artefacts/1618683.png
#  extracting: hit-images-final/artefacts/1618684.png
#  extracting: hit-images-final/artefacts/1618686.png
#  extracting: hit-images-final/artefacts/1619717.png
#  extracting: hit-images-final/artefacts/1619718.png
#  extracting: hit-images-final/artefacts/1620483.png
#  extracting: hit-images-final/artefacts/1625052.png
#  extracting: hit-images-final/artefacts/1625296.png
#  extracting: hit-images-final/artefacts/1625975.png
#  extracting: hit-images-final/artefacts/1625977.png
#  extracting: hit-images-final/artefacts/1625978.png
#  extracting: hit-images-final/artefacts/1625979.png
#  extracting: hit-images-final/artefacts/1627321.png
#  extracting: hit-images-final/artefacts/1627325.png
#  extracting: hit-images-final/artefacts/1627417.png
#  extracting: hit-images-final/artefacts/1627514.png
#  extracting: hit-images-final/artefacts/1627523.png
#  extracting: hit-images-final/artefacts/1627545.png
#  extracting: hit-images-final/artefacts/1627657.png
#  extracting: hit-images-final/artefacts/1627659.png
#  extracting: hit-images-final/artefacts/1627865.png
#  extracting: hit-images-final/artefacts/1627871.png
#  extracting: hit-images-final/artefacts/1627878.png
#  extracting: hit-images-final/artefacts/1627879.png
#  extracting: hit-images-final/artefacts/1627880.png
#  extracting: hit-images-final/artefacts/1627885.png
#  extracting: hit-images-final/artefacts/1627886.png
#  extracting: hit-images-final/artefacts/1627888.png
#  extracting: hit-images-final/artefacts/1627889.png
#  extracting: hit-images-final/artefacts/1628274.png
#  extracting: hit-images-final/artefacts/1631769.png
#  extracting: hit-images-final/artefacts/1631778.png
#  extracting: hit-images-final/artefacts/1631785.png
#  extracting: hit-images-final/artefacts/1634191.png
#  extracting: hit-images-final/artefacts/1634192.png
#  extracting: hit-images-final/artefacts/1634195.png
#  extracting: hit-images-final/artefacts/1634196.png
#  extracting: hit-images-final/artefacts/1634197.png
#  extracting: hit-images-final/artefacts/1634198.png
#  extracting: hit-images-final/artefacts/1634647.png
#  extracting: hit-images-final/artefacts/1636216.png
#  extracting: hit-images-final/artefacts/1636220.png
#  extracting: hit-images-final/artefacts/1636221.png
#  extracting: hit-images-final/artefacts/1637101.png
#  extracting: hit-images-final/artefacts/1637102.png
#  extracting: hit-images-final/artefacts/1637105.png
#  extracting: hit-images-final/artefacts/1637122.png
#  extracting: hit-images-final/artefacts/1637124.png
#  extracting: hit-images-final/artefacts/1637128.png
#  extracting: hit-images-final/artefacts/1637178.png
#  extracting: hit-images-final/artefacts/1637180.png
#  extracting: hit-images-final/artefacts/1637181.png
#  extracting: hit-images-final/artefacts/1637185.png
#  extracting: hit-images-final/artefacts/1637187.png
#  extracting: hit-images-final/artefacts/1637188.png
#  extracting: hit-images-final/artefacts/1641409.png
#  extracting: hit-images-final/artefacts/1641411.png
#  extracting: hit-images-final/artefacts/1641412.png
#  extracting: hit-images-final/artefacts/1641413.png
#  extracting: hit-images-final/artefacts/1641414.png
#  extracting: hit-images-final/artefacts/1641415.png
#  extracting: hit-images-final/artefacts/1641416.png
#  extracting: hit-images-final/artefacts/1641417.png
#  extracting: hit-images-final/artefacts/1641419.png
#  extracting: hit-images-final/artefacts/1641420.png
#  extracting: hit-images-final/artefacts/1641421.png
#  extracting: hit-images-final/artefacts/1641422.png
#  extracting: hit-images-final/artefacts/1642077.png
#  extracting: hit-images-final/artefacts/1642078.png
#  extracting: hit-images-final/artefacts/1642079.png
#  extracting: hit-images-final/artefacts/1642082.png
#  extracting: hit-images-final/artefacts/1642555.png
#  extracting: hit-images-final/artefacts/1642557.png
#  extracting: hit-images-final/artefacts/1643514.png
#  extracting: hit-images-final/artefacts/1643524.png
#  extracting: hit-images-final/artefacts/1643725.png
#  extracting: hit-images-final/artefacts/1643728.png
#  extracting: hit-images-final/artefacts/1643729.png
#  extracting: hit-images-final/artefacts/1643768.png
#  extracting: hit-images-final/artefacts/1643984.png
#  extracting: hit-images-final/artefacts/1643985.png
#  extracting: hit-images-final/artefacts/1644130.png
#  extracting: hit-images-final/artefacts/1645127.png
#  extracting: hit-images-final/artefacts/1646052.png
#  extracting: hit-images-final/artefacts/1646393.png
#  extracting: hit-images-final/artefacts/1646631.png
#  extracting: hit-images-final/artefacts/1649484.png
#  extracting: hit-images-final/artefacts/1649485.png
#  extracting: hit-images-final/artefacts/1649486.png
#  extracting: hit-images-final/artefacts/1649487.png
#  extracting: hit-images-final/artefacts/1650388.png
#  extracting: hit-images-final/artefacts/1650394.png
#  extracting: hit-images-final/artefacts/1650395.png
#  extracting: hit-images-final/artefacts/1650396.png
#  extracting: hit-images-final/artefacts/1650397.png
#  extracting: hit-images-final/artefacts/1650398.png
#  extracting: hit-images-final/artefacts/1650405.png
#  extracting: hit-images-final/artefacts/1652573.png
#  extracting: hit-images-final/artefacts/1653165.png
#  extracting: hit-images-final/artefacts/1654502.png
#  extracting: hit-images-final/artefacts/1654516.png
#  extracting: hit-images-final/artefacts/1654519.png
#  extracting: hit-images-final/artefacts/1655126.png
#   inflating: hit-images-final/artefacts/1657021.png
#  extracting: hit-images-final/artefacts/1657023.png
#  extracting: hit-images-final/artefacts/1657478.png
#  extracting: hit-images-final/artefacts/1657479.png
#  extracting: hit-images-final/artefacts/1657480.png
#  extracting: hit-images-final/artefacts/1657481.png
#  extracting: hit-images-final/artefacts/1657485.png
#  extracting: hit-images-final/artefacts/1657486.png
#  extracting: hit-images-final/artefacts/1657487.png
#  extracting: hit-images-final/artefacts/1657489.png
#  extracting: hit-images-final/artefacts/1657492.png
#  extracting: hit-images-final/artefacts/1657493.png
#  extracting: hit-images-final/artefacts/1660040.png
#  extracting: hit-images-final/artefacts/1660041.png
#  extracting: hit-images-final/artefacts/1660042.png
#  extracting: hit-images-final/artefacts/1660491.png
#  extracting: hit-images-final/artefacts/1660498.png
#  extracting: hit-images-final/artefacts/1660500.png
#  extracting: hit-images-final/artefacts/1660501.png
#  extracting: hit-images-final/artefacts/1660502.png
#  extracting: hit-images-final/artefacts/1660504.png
#  extracting: hit-images-final/artefacts/1660680.png
#  extracting: hit-images-final/artefacts/1660683.png
#  extracting: hit-images-final/artefacts/1661566.png
#  extracting: hit-images-final/artefacts/1661567.png
#  extracting: hit-images-final/artefacts/1661569.png
#  extracting: hit-images-final/artefacts/1661570.png
#  extracting: hit-images-final/artefacts/1662830.png
#  extracting: hit-images-final/artefacts/1662831.png
#  extracting: hit-images-final/artefacts/1664926.png
#  extracting: hit-images-final/artefacts/1665515.png
#  extracting: hit-images-final/artefacts/1665629.png
#  extracting: hit-images-final/artefacts/1665652.png
#  extracting: hit-images-final/artefacts/1666337.png
#  extracting: hit-images-final/artefacts/1666342.png
#  extracting: hit-images-final/artefacts/1667079.png
#  extracting: hit-images-final/artefacts/1667113.png
#  extracting: hit-images-final/artefacts/1667149.png
#  extracting: hit-images-final/artefacts/1667173.png
#  extracting: hit-images-final/artefacts/1667174.png
#  extracting: hit-images-final/artefacts/1667175.png
#  extracting: hit-images-final/artefacts/1667178.png
#  extracting: hit-images-final/artefacts/1667180.png
#  extracting: hit-images-final/artefacts/1667183.png
#  extracting: hit-images-final/artefacts/1667200.png
#  extracting: hit-images-final/artefacts/1669921.png
#  extracting: hit-images-final/artefacts/1669947.png
#  extracting: hit-images-final/artefacts/1669949.png
#  extracting: hit-images-final/artefacts/1669950.png
#  extracting: hit-images-final/artefacts/1669951.png
#  extracting: hit-images-final/artefacts/1669952.png
#  extracting: hit-images-final/artefacts/1669953.png
#  extracting: hit-images-final/artefacts/1670106.png
#  extracting: hit-images-final/artefacts/1670107.png
#  extracting: hit-images-final/artefacts/1670898.png
#  extracting: hit-images-final/artefacts/1671134.png
#  extracting: hit-images-final/artefacts/1683483.png
#  extracting: hit-images-final/artefacts/1683484.png
#  extracting: hit-images-final/artefacts/1683485.png
#  extracting: hit-images-final/artefacts/1683486.png
#  extracting: hit-images-final/artefacts/1683487.png
#  extracting: hit-images-final/artefacts/1683488.png
#  extracting: hit-images-final/artefacts/1683489.png
#  extracting: hit-images-final/artefacts/1683490.png
#  extracting: hit-images-final/artefacts/1683491.png
#  extracting: hit-images-final/artefacts/1683492.png
#  extracting: hit-images-final/artefacts/1683493.png
#  extracting: hit-images-final/artefacts/1683494.png
#  extracting: hit-images-final/artefacts/1683495.png
#  extracting: hit-images-final/artefacts/1683496.png
#  extracting: hit-images-final/artefacts/1683497.png
#  extracting: hit-images-final/artefacts/1683745.png
#  extracting: hit-images-final/artefacts/1684641.png
#  extracting: hit-images-final/artefacts/1684643.png
#  extracting: hit-images-final/artefacts/1684645.png
#  extracting: hit-images-final/artefacts/1684647.png
#  extracting: hit-images-final/artefacts/1684649.png
#  extracting: hit-images-final/artefacts/1687400.png
#  extracting: hit-images-final/artefacts/1688534.png
#  extracting: hit-images-final/artefacts/1688535.png
#  extracting: hit-images-final/artefacts/1688536.png
#  extracting: hit-images-final/artefacts/1688538.png
#  extracting: hit-images-final/artefacts/1688539.png
#  extracting: hit-images-final/artefacts/1688540.png
#  extracting: hit-images-final/artefacts/1688541.png
#  extracting: hit-images-final/artefacts/1688543.png
#  extracting: hit-images-final/artefacts/1688544.png
#  extracting: hit-images-final/artefacts/1688547.png
#  extracting: hit-images-final/artefacts/1688553.png
#   inflating: hit-images-final/artefacts/1690991.png
#  extracting: hit-images-final/artefacts/2400865.png
#  extracting: hit-images-final/artefacts/2400868.png
#  extracting: hit-images-final/artefacts/2400870.png
#  extracting: hit-images-final/artefacts/2400872.png
#  extracting: hit-images-final/artefacts/2400874.png
#  extracting: hit-images-final/artefacts/2400875.png
#  extracting: hit-images-final/artefacts/2400877.png
#  extracting: hit-images-final/artefacts/2406794.png
#  extracting: hit-images-final/artefacts/2407974.png
#  extracting: hit-images-final/artefacts/2408448.png
#  extracting: hit-images-final/artefacts/2409684.png
#  extracting: hit-images-final/artefacts/2409685.png
#  extracting: hit-images-final/artefacts/2409686.png
#  extracting: hit-images-final/artefacts/2409689.png
#  extracting: hit-images-final/artefacts/2409690.png
#  extracting: hit-images-final/artefacts/2409691.png
#  extracting: hit-images-final/artefacts/2409692.png
#  extracting: hit-images-final/artefacts/2409693.png
#  extracting: hit-images-final/artefacts/2409694.png
#  extracting: hit-images-final/artefacts/2409696.png
#  extracting: hit-images-final/artefacts/2409697.png
#  extracting: hit-images-final/artefacts/2409698.png
#  extracting: hit-images-final/artefacts/2409699.png
#  extracting: hit-images-final/artefacts/2409700.png
#  extracting: hit-images-final/artefacts/2409701.png
#  extracting: hit-images-final/artefacts/2409702.png
#  extracting: hit-images-final/artefacts/2409703.png
#  extracting: hit-images-final/artefacts/2409706.png
#  extracting: hit-images-final/artefacts/2410186.png
#  extracting: hit-images-final/artefacts/2410187.png
#  extracting: hit-images-final/artefacts/2410188.png
#  extracting: hit-images-final/artefacts/2410190.png
#  extracting: hit-images-final/artefacts/2410192.png
#  extracting: hit-images-final/artefacts/2410196.png
#  extracting: hit-images-final/artefacts/2411752.png
#  extracting: hit-images-final/artefacts/2411753.png
#  extracting: hit-images-final/artefacts/2411754.png
#  extracting: hit-images-final/artefacts/2411755.png
#  extracting: hit-images-final/artefacts/2411756.png
#  extracting: hit-images-final/artefacts/2411757.png
#  extracting: hit-images-final/artefacts/2411758.png
#  extracting: hit-images-final/artefacts/2419980.png
#  extracting: hit-images-final/artefacts/2419990.png
#  extracting: hit-images-final/artefacts/2420546.png
#  extracting: hit-images-final/artefacts/2423912.png
#  extracting: hit-images-final/artefacts/2423919.png
#  extracting: hit-images-final/artefacts/2426566.png
#  extracting: hit-images-final/artefacts/2427534.png
#  extracting: hit-images-final/artefacts/2427535.png
#  extracting: hit-images-final/artefacts/2427536.png
#  extracting: hit-images-final/artefacts/2427584.png
#  extracting: hit-images-final/artefacts/2427585.png
#  extracting: hit-images-final/artefacts/2432339.png
#  extracting: hit-images-final/artefacts/2432466.png
#  extracting: hit-images-final/artefacts/2432468.png
#  extracting: hit-images-final/artefacts/2432509.png
#  extracting: hit-images-final/artefacts/2432510.png
#  extracting: hit-images-final/artefacts/2432511.png
#  extracting: hit-images-final/artefacts/2432512.png
#  extracting: hit-images-final/artefacts/2432513.png
#  extracting: hit-images-final/artefacts/2436434.png
#  extracting: hit-images-final/artefacts/2436928.png
#  extracting: hit-images-final/artefacts/2436929.png
#  extracting: hit-images-final/artefacts/2436931.png
#  extracting: hit-images-final/artefacts/2437003.png
#  extracting: hit-images-final/artefacts/2437468.png
#   inflating: hit-images-final/artefacts/2440228.png
#  extracting: hit-images-final/artefacts/2443385.png
#  extracting: hit-images-final/artefacts/2443928.png
#  extracting: hit-images-final/artefacts/2445104.png
#  extracting: hit-images-final/artefacts/2445354.png
#  extracting: hit-images-final/artefacts/2445387.png
#  extracting: hit-images-final/artefacts/2445793.png
#  extracting: hit-images-final/artefacts/2445794.png
#  extracting: hit-images-final/artefacts/2446556.png
#  extracting: hit-images-final/artefacts/2450190.png
#  extracting: hit-images-final/artefacts/2452164.png
#  extracting: hit-images-final/artefacts/2452680.png
#  extracting: hit-images-final/artefacts/2452681.png
#  extracting: hit-images-final/artefacts/2452971.png
#  extracting: hit-images-final/artefacts/2453172.png
#  extracting: hit-images-final/artefacts/2453173.png
#  extracting: hit-images-final/artefacts/2453174.png
#  extracting: hit-images-final/artefacts/2453176.png
#  extracting: hit-images-final/artefacts/2453188.png
#  extracting: hit-images-final/artefacts/2453189.png
#  extracting: hit-images-final/artefacts/2453925.png
#  extracting: hit-images-final/artefacts/2454578.png
#  extracting: hit-images-final/artefacts/2454580.png
#  extracting: hit-images-final/artefacts/2454582.png
#  extracting: hit-images-final/artefacts/2454583.png
#  extracting: hit-images-final/artefacts/2455949.png
#  extracting: hit-images-final/artefacts/2456427.png
#  extracting: hit-images-final/artefacts/2458460.png
#  extracting: hit-images-final/artefacts/2460046.png
#  extracting: hit-images-final/artefacts/2460047.png
#  extracting: hit-images-final/artefacts/2460049.png
#  extracting: hit-images-final/artefacts/2460051.png
#  extracting: hit-images-final/artefacts/2460053.png
#  extracting: hit-images-final/artefacts/2460054.png
#  extracting: hit-images-final/artefacts/2460056.png
#  extracting: hit-images-final/artefacts/2460061.png
#  extracting: hit-images-final/artefacts/2460063.png
#  extracting: hit-images-final/artefacts/2460065.png
#  extracting: hit-images-final/artefacts/2460069.png
#  extracting: hit-images-final/artefacts/2460070.png
#  extracting: hit-images-final/artefacts/2460071.png
#  extracting: hit-images-final/artefacts/2460073.png
#  extracting: hit-images-final/artefacts/2466129.png
#  extracting: hit-images-final/artefacts/2466131.png
#  extracting: hit-images-final/artefacts/2466133.png
#  extracting: hit-images-final/artefacts/2466134.png
#  extracting: hit-images-final/artefacts/2466135.png
#  extracting: hit-images-final/artefacts/2466137.png
#  extracting: hit-images-final/artefacts/2466139.png
#  extracting: hit-images-final/artefacts/2466140.png
#  extracting: hit-images-final/artefacts/2466141.png
#  extracting: hit-images-final/artefacts/2466145.png
#  extracting: hit-images-final/artefacts/2466147.png
#  extracting: hit-images-final/artefacts/2466149.png
#  extracting: hit-images-final/artefacts/2466150.png
#  extracting: hit-images-final/artefacts/2466151.png
#  extracting: hit-images-final/artefacts/2466153.png
#  extracting: hit-images-final/artefacts/2466154.png
#  extracting: hit-images-final/artefacts/2466157.png
#  extracting: hit-images-final/artefacts/2466158.png
#  extracting: hit-images-final/artefacts/2469337.png
#  extracting: hit-images-final/artefacts/2471668.png
#  extracting: hit-images-final/artefacts/2474081.png
#  extracting: hit-images-final/artefacts/2474199.png
#  extracting: hit-images-final/artefacts/2474691.png
#  extracting: hit-images-final/artefacts/2475063.png
#  extracting: hit-images-final/artefacts/2475812.png
#  extracting: hit-images-final/artefacts/2476400.png
#  extracting: hit-images-final/artefacts/2476402.png
#  extracting: hit-images-final/artefacts/2476404.png
#  extracting: hit-images-final/artefacts/2476405.png
#  extracting: hit-images-final/artefacts/2476406.png
#  extracting: hit-images-final/artefacts/2476407.png
#  extracting: hit-images-final/artefacts/2476408.png
#  extracting: hit-images-final/artefacts/2476409.png
#  extracting: hit-images-final/artefacts/2476410.png
#  extracting: hit-images-final/artefacts/2476411.png
#  extracting: hit-images-final/artefacts/2476412.png
#  extracting: hit-images-final/artefacts/2476980.png
#  extracting: hit-images-final/artefacts/2479317.png
#  extracting: hit-images-final/artefacts/2480178.png
#  extracting: hit-images-final/artefacts/2480185.png
#  extracting: hit-images-final/artefacts/2480186.png
#  extracting: hit-images-final/artefacts/2480187.png
#  extracting: hit-images-final/artefacts/2480188.png
#  extracting: hit-images-final/artefacts/2480189.png
#  extracting: hit-images-final/artefacts/2481230.png
#   inflating: hit-images-final/artefacts/2495763.png
#  extracting: hit-images-final/artefacts/2497028.png
#  extracting: hit-images-final/artefacts/2497529.png
#  extracting: hit-images-final/artefacts/2497530.png
#  extracting: hit-images-final/artefacts/2498189.png
#  extracting: hit-images-final/artefacts/2498191.png
#  extracting: hit-images-final/artefacts/2498192.png
#  extracting: hit-images-final/artefacts/2498305.png
#  extracting: hit-images-final/artefacts/2498306.png
#  extracting: hit-images-final/artefacts/2498308.png
#  extracting: hit-images-final/artefacts/2498376.png
#  extracting: hit-images-final/artefacts/2498377.png
#  extracting: hit-images-final/artefacts/2498378.png
#  extracting: hit-images-final/artefacts/2498379.png
#  extracting: hit-images-final/artefacts/2498380.png
#  extracting: hit-images-final/artefacts/2498381.png
#  extracting: hit-images-final/artefacts/2498382.png
#  extracting: hit-images-final/artefacts/2498383.png
#  extracting: hit-images-final/artefacts/2498385.png
#  extracting: hit-images-final/artefacts/2498386.png
#  extracting: hit-images-final/artefacts/2498387.png
#  extracting: hit-images-final/artefacts/2498421.png
#  extracting: hit-images-final/artefacts/2498422.png
#  extracting: hit-images-final/artefacts/2498462.png
#  extracting: hit-images-final/artefacts/2498910.png
#  extracting: hit-images-final/artefacts/2498936.png
#  extracting: hit-images-final/artefacts/2498937.png
#  extracting: hit-images-final/artefacts/2498953.png
#  extracting: hit-images-final/artefacts/2498954.png
#  extracting: hit-images-final/artefacts/2499017.png
#  extracting: hit-images-final/artefacts/2499885.png
#  extracting: hit-images-final/artefacts/2499886.png
#  extracting: hit-images-final/artefacts/2499887.png
#  extracting: hit-images-final/artefacts/2499888.png
#  extracting: hit-images-final/artefacts/2500823.png
#  extracting: hit-images-final/artefacts/2500824.png
#  extracting: hit-images-final/artefacts/2500825.png
#  extracting: hit-images-final/artefacts/2500826.png
#  extracting: hit-images-final/artefacts/2500830.png
#  extracting: hit-images-final/artefacts/2500838.png
#  extracting: hit-images-final/artefacts/2500841.png
#  extracting: hit-images-final/artefacts/2500882.png
#  extracting: hit-images-final/artefacts/2500921.png
#  extracting: hit-images-final/artefacts/2500922.png
#   inflating: hit-images-final/artefacts/2508080.png
#  extracting: hit-images-final/artefacts/2508442.png
#  extracting: hit-images-final/artefacts/2508443.png
#  extracting: hit-images-final/artefacts/2508444.png
#  extracting: hit-images-final/artefacts/2508445.png
#  extracting: hit-images-final/artefacts/2508446.png
#  extracting: hit-images-final/artefacts/2508447.png
#  extracting: hit-images-final/artefacts/2508448.png
#  extracting: hit-images-final/artefacts/2508449.png
#   inflating: hit-images-final/artefacts/2508741.png
#  extracting: hit-images-final/artefacts/2511550.png
#  extracting: hit-images-final/artefacts/2512119.png
#  extracting: hit-images-final/artefacts/2512120.png
#  extracting: hit-images-final/artefacts/2512121.png
#  extracting: hit-images-final/artefacts/2512420.png
#  extracting: hit-images-final/artefacts/2512840.png
#  extracting: hit-images-final/artefacts/2512842.png
#  extracting: hit-images-final/artefacts/2513554.png
#  extracting: hit-images-final/artefacts/2513576.png
#  extracting: hit-images-final/artefacts/2513603.png
#  extracting: hit-images-final/artefacts/2514618.png
#  extracting: hit-images-final/artefacts/2515099.png
#  extracting: hit-images-final/artefacts/2515100.png
#  extracting: hit-images-final/artefacts/2515101.png
#  extracting: hit-images-final/artefacts/2516238.png
#  extracting: hit-images-final/artefacts/2516416.png
#  extracting: hit-images-final/artefacts/2516418.png
#  extracting: hit-images-final/artefacts/2516420.png
#  extracting: hit-images-final/artefacts/2516421.png
#  extracting: hit-images-final/artefacts/2516708.png
#  extracting: hit-images-final/artefacts/2516709.png
#  extracting: hit-images-final/artefacts/2516711.png
#   inflating: hit-images-final/artefacts/2520087.png
#  extracting: hit-images-final/artefacts/2520610.png
#  extracting: hit-images-final/artefacts/2521380.png
#  extracting: hit-images-final/artefacts/2521713.png
#  extracting: hit-images-final/artefacts/2521795.png
#  extracting: hit-images-final/artefacts/2523556.png
#  extracting: hit-images-final/artefacts/2525285.png
#  extracting: hit-images-final/artefacts/2525838.png
#  extracting: hit-images-final/artefacts/2529566.png
#  extracting: hit-images-final/artefacts/2529567.png
#  extracting: hit-images-final/artefacts/2529568.png
#  extracting: hit-images-final/artefacts/2529616.png
#  extracting: hit-images-final/artefacts/2529617.png
#  extracting: hit-images-final/artefacts/2534335.png
#  extracting: hit-images-final/artefacts/2534336.png
#  extracting: hit-images-final/artefacts/2534337.png
#  extracting: hit-images-final/artefacts/2534342.png
#  extracting: hit-images-final/artefacts/2534343.png
#  extracting: hit-images-final/artefacts/2534345.png
#  extracting: hit-images-final/artefacts/2534347.png
#  extracting: hit-images-final/artefacts/2534349.png
#  extracting: hit-images-final/artefacts/2534588.png
#  extracting: hit-images-final/artefacts/2535467.png
#  extracting: hit-images-final/artefacts/2535680.png
#  extracting: hit-images-final/artefacts/2535681.png
#  extracting: hit-images-final/artefacts/2535901.png
#   inflating: hit-images-final/artefacts/2536209.png
#  extracting: hit-images-final/artefacts/2538769.png
#  extracting: hit-images-final/artefacts/2538770.png
#  extracting: hit-images-final/artefacts/2538771.png
#  extracting: hit-images-final/artefacts/2538772.png
#  extracting: hit-images-final/artefacts/2538773.png
#  extracting: hit-images-final/artefacts/2538774.png
#  extracting: hit-images-final/artefacts/2539901.png
#  extracting: hit-images-final/artefacts/2539904.png
#  extracting: hit-images-final/artefacts/2540131.png
#  extracting: hit-images-final/artefacts/2542019.png
#  extracting: hit-images-final/artefacts/2542765.png
#   inflating: hit-images-final/artefacts/2545365.png
#  extracting: hit-images-final/artefacts/2545955.png
#  extracting: hit-images-final/artefacts/2545956.png
#  extracting: hit-images-final/artefacts/2545957.png
#  extracting: hit-images-final/artefacts/2545958.png
#  extracting: hit-images-final/artefacts/2546351.png
#  extracting: hit-images-final/artefacts/2546352.png
#  extracting: hit-images-final/artefacts/2546353.png
#  extracting: hit-images-final/artefacts/2546354.png
#  extracting: hit-images-final/artefacts/2546355.png
#  extracting: hit-images-final/artefacts/2546356.png
#  extracting: hit-images-final/artefacts/2546357.png
#  extracting: hit-images-final/artefacts/2546358.png
#  extracting: hit-images-final/artefacts/2546359.png
#   inflating: hit-images-final/artefacts/2546594.png
#  extracting: hit-images-final/artefacts/2546751.png
#  extracting: hit-images-final/artefacts/2546752.png
#  extracting: hit-images-final/artefacts/2546753.png
#  extracting: hit-images-final/artefacts/2546881.png
#  extracting: hit-images-final/artefacts/2546915.png
#  extracting: hit-images-final/artefacts/2546917.png
#  extracting: hit-images-final/artefacts/2546918.png
#  extracting: hit-images-final/artefacts/2546919.png
#  extracting: hit-images-final/artefacts/2546920.png
#  extracting: hit-images-final/artefacts/2546923.png
#  extracting: hit-images-final/artefacts/2546927.png
#  extracting: hit-images-final/artefacts/2546928.png
#  extracting: hit-images-final/artefacts/2546929.png
#  extracting: hit-images-final/artefacts/2546932.png
#  extracting: hit-images-final/artefacts/2546943.png
#   inflating: hit-images-final/artefacts/2546944.png
#  extracting: hit-images-final/artefacts/2546945.png
#  extracting: hit-images-final/artefacts/2546947.png
#  extracting: hit-images-final/artefacts/2547317.png
#  extracting: hit-images-final/artefacts/2547318.png
#  extracting: hit-images-final/artefacts/2547319.png
#  extracting: hit-images-final/artefacts/2547320.png
#  extracting: hit-images-final/artefacts/2547321.png
#  extracting: hit-images-final/artefacts/2547322.png
#  extracting: hit-images-final/artefacts/2547323.png
#  extracting: hit-images-final/artefacts/2547325.png
#  extracting: hit-images-final/artefacts/2547328.png
#  extracting: hit-images-final/artefacts/2547980.png
#  extracting: hit-images-final/artefacts/2547982.png
#  extracting: hit-images-final/artefacts/2547983.png
#  extracting: hit-images-final/artefacts/2549432.png
#  extracting: hit-images-final/artefacts/2549435.png
#  extracting: hit-images-final/artefacts/2549436.png
#  extracting: hit-images-final/artefacts/2549437.png
#  extracting: hit-images-final/artefacts/2549452.png
#  extracting: hit-images-final/artefacts/2549453.png
#  extracting: hit-images-final/artefacts/2549598.png
#  extracting: hit-images-final/artefacts/2555366.png
#  extracting: hit-images-final/artefacts/2555754.png
#  extracting: hit-images-final/artefacts/2555756.png
#  extracting: hit-images-final/artefacts/2555759.png
#  extracting: hit-images-final/artefacts/2559005.png
#  extracting: hit-images-final/artefacts/2559006.png
#  extracting: hit-images-final/artefacts/2559022.png
#  extracting: hit-images-final/artefacts/2559023.png
#  extracting: hit-images-final/artefacts/2559024.png
#  extracting: hit-images-final/artefacts/2559026.png
#  extracting: hit-images-final/artefacts/2559027.png
#  extracting: hit-images-final/artefacts/2559028.png
#  extracting: hit-images-final/artefacts/2559029.png
#  extracting: hit-images-final/artefacts/2559944.png
#  extracting: hit-images-final/artefacts/2560845.png
#  extracting: hit-images-final/artefacts/2560846.png
#  extracting: hit-images-final/artefacts/2560850.png
#  extracting: hit-images-final/artefacts/2560851.png
#  extracting: hit-images-final/artefacts/2560852.png
#  extracting: hit-images-final/artefacts/2560853.png
#  extracting: hit-images-final/artefacts/2560974.png
#   inflating: hit-images-final/artefacts/2561303.png
#  extracting: hit-images-final/artefacts/2561399.png
#   inflating: hit-images-final/artefacts/2561400.png
#  extracting: hit-images-final/artefacts/2574911.png
#  extracting: hit-images-final/artefacts/2574931.png
#  extracting: hit-images-final/artefacts/2575603.png
#  extracting: hit-images-final/artefacts/2577806.png
#  extracting: hit-images-final/artefacts/2577811.png
#  extracting: hit-images-final/artefacts/2577812.png
#  extracting: hit-images-final/artefacts/2580390.png
#  extracting: hit-images-final/artefacts/2580915.png
#  extracting: hit-images-final/artefacts/2581253.png
#  extracting: hit-images-final/artefacts/2581552.png
#  extracting: hit-images-final/artefacts/2581553.png
#  extracting: hit-images-final/artefacts/2581555.png
#  extracting: hit-images-final/artefacts/2581704.png
#  extracting: hit-images-final/artefacts/2581706.png
#  extracting: hit-images-final/artefacts/2581707.png
#  extracting: hit-images-final/artefacts/2581708.png
#  extracting: hit-images-final/artefacts/2581709.png
#  extracting: hit-images-final/artefacts/2581710.png
#  extracting: hit-images-final/artefacts/2581711.png
#  extracting: hit-images-final/artefacts/2581712.png
#  extracting: hit-images-final/artefacts/2581713.png
#  extracting: hit-images-final/artefacts/2581715.png
#  extracting: hit-images-final/artefacts/2584079.png
#  extracting: hit-images-final/artefacts/2597932.png
#  extracting: hit-images-final/artefacts/2597942.png
#  extracting: hit-images-final/artefacts/2597944.png
#  extracting: hit-images-final/artefacts/2598012.png
#  extracting: hit-images-final/artefacts/2598188.png
#  extracting: hit-images-final/artefacts/2598192.png
#  extracting: hit-images-final/artefacts/2598199.png
#  extracting: hit-images-final/artefacts/2598200.png
#  extracting: hit-images-final/artefacts/2598614.png
#  extracting: hit-images-final/artefacts/2598616.png
#  extracting: hit-images-final/artefacts/2599731.png
#  extracting: hit-images-final/artefacts/2599752.png
#  extracting: hit-images-final/artefacts/2599767.png
#  extracting: hit-images-final/artefacts/5202352.png
#  extracting: hit-images-final/artefacts/5206853.png
#  extracting: hit-images-final/artefacts/5211132.png
#  extracting: hit-images-final/artefacts/5211242.png
#  extracting: hit-images-final/artefacts/5212103.png
#  extracting: hit-images-final/artefacts/5214462.png
#  extracting: hit-images-final/artefacts/5222743.png
#   inflating: hit-images-final/artefacts/5225363.png
#  extracting: hit-images-final/artefacts/5236335.png
#  extracting: hit-images-final/artefacts/5237484.png
#   inflating: hit-images-final/artefacts/5242990.png
#  extracting: hit-images-final/artefacts/5249458.png
#  extracting: hit-images-final/artefacts/5251744.png
#  extracting: hit-images-final/artefacts/5251757.png
#  extracting: hit-images-final/artefacts/5252049.png
#  extracting: hit-images-final/artefacts/5253112.png
#  extracting: hit-images-final/artefacts/5265417.png
#   inflating: hit-images-final/artefacts/5270431.png
#  extracting: hit-images-final/artefacts/5277767.png
#   inflating: hit-images-final/artefacts/5278705.png
#  extracting: hit-images-final/artefacts/5281089.png
#  extracting: hit-images-final/artefacts/5282060.png
#  extracting: hit-images-final/artefacts/5282061.png
#  extracting: hit-images-final/artefacts/5282062.png
#  extracting: hit-images-final/artefacts/5282887.png
#  extracting: hit-images-final/artefacts/5283018.png
#  extracting: hit-images-final/artefacts/5283115.png
#  extracting: hit-images-final/artefacts/5284305.png
#  extracting: hit-images-final/artefacts/5286353.png
#  extracting: hit-images-final/artefacts/5286936.png
#  extracting: hit-images-final/artefacts/5288422.png
#  extracting: hit-images-final/artefacts/5288686.png
#  extracting: hit-images-final/artefacts/5290346.png
#  extracting: hit-images-final/artefacts/5296073.png
#   inflating: hit-images-final/artefacts/5300049.png
#  extracting: hit-images-final/artefacts/9403145.png
#  extracting: hit-images-final/artefacts/9403146.png
#  extracting: hit-images-final/artefacts/9407114.png
#  extracting: hit-images-final/artefacts/9408445.png
#  extracting: hit-images-final/artefacts/9408634.png
#  extracting: hit-images-final/artefacts/9408825.png
#  extracting: hit-images-final/artefacts/9408826.png
#  extracting: hit-images-final/artefacts/9412347.png
#  extracting: hit-images-final/artefacts/9412349.png
#  extracting: hit-images-final/artefacts/9412351.png
#  extracting: hit-images-final/artefacts/9412352.png
#  extracting: hit-images-final/artefacts/9412354.png
#  extracting: hit-images-final/artefacts/9412356.png
#  extracting: hit-images-final/artefacts/9412357.png
#  extracting: hit-images-final/artefacts/9415587.png
#  extracting: hit-images-final/artefacts/9415650.png
#  extracting: hit-images-final/artefacts/9415651.png
#  extracting: hit-images-final/artefacts/9415652.png
#  extracting: hit-images-final/artefacts/9415653.png
#  extracting: hit-images-final/artefacts/9415654.png
#  extracting: hit-images-final/artefacts/9415655.png
#  extracting: hit-images-final/artefacts/9415656.png
#  extracting: hit-images-final/artefacts/9415658.png
#  extracting: hit-images-final/artefacts/9415659.png
#  extracting: hit-images-final/artefacts/9415660.png
#  extracting: hit-images-final/artefacts/9415661.png
#  extracting: hit-images-final/artefacts/9415662.png
#  extracting: hit-images-final/artefacts/9415663.png
#  extracting: hit-images-final/artefacts/9416223.png
#  extracting: hit-images-final/artefacts/9416448.png
#  extracting: hit-images-final/artefacts/9417572.png
#  extracting: hit-images-final/artefacts/9417573.png
#  extracting: hit-images-final/artefacts/9417574.png
#  extracting: hit-images-final/artefacts/9417575.png
#  extracting: hit-images-final/artefacts/9417576.png
#  extracting: hit-images-final/artefacts/9417577.png
#  extracting: hit-images-final/artefacts/9417592.png
#  extracting: hit-images-final/artefacts/9417593.png
#  extracting: hit-images-final/artefacts/9417594.png
#  extracting: hit-images-final/artefacts/9417595.png
#  extracting: hit-images-final/artefacts/9417596.png
#  extracting: hit-images-final/artefacts/9417597.png
#  extracting: hit-images-final/artefacts/9417599.png
#  extracting: hit-images-final/artefacts/9417600.png
#  extracting: hit-images-final/artefacts/9417601.png
#  extracting: hit-images-final/artefacts/9417618.png
#  extracting: hit-images-final/artefacts/9417619.png
#  extracting: hit-images-final/artefacts/9417620.png
#  extracting: hit-images-final/artefacts/9417621.png
#  extracting: hit-images-final/artefacts/9417622.png
#  extracting: hit-images-final/artefacts/9417623.png
#  extracting: hit-images-final/artefacts/9417624.png
#  extracting: hit-images-final/artefacts/9417625.png
#  extracting: hit-images-final/artefacts/9417626.png
#  extracting: hit-images-final/artefacts/9417653.png
#  extracting: hit-images-final/artefacts/9417654.png
#  extracting: hit-images-final/artefacts/9417655.png
#  extracting: hit-images-final/artefacts/9417656.png
#  extracting: hit-images-final/artefacts/9417657.png
#  extracting: hit-images-final/artefacts/9417658.png
#  extracting: hit-images-final/artefacts/9417659.png
#  extracting: hit-images-final/artefacts/9417661.png
#  extracting: hit-images-final/artefacts/9417662.png
#  extracting: hit-images-final/artefacts/9417663.png
#  extracting: hit-images-final/artefacts/9417664.png
#  extracting: hit-images-final/artefacts/9417665.png
#  extracting: hit-images-final/artefacts/9417666.png
#  extracting: hit-images-final/artefacts/9417667.png
#  extracting: hit-images-final/artefacts/9417668.png
#  extracting: hit-images-final/artefacts/9417669.png
#  extracting: hit-images-final/artefacts/9417670.png
#  extracting: hit-images-final/artefacts/9417671.png
#  extracting: hit-images-final/artefacts/9417672.png
#  extracting: hit-images-final/artefacts/9417673.png
#  extracting: hit-images-final/artefacts/9417674.png
#  extracting: hit-images-final/artefacts/9417675.png
#  extracting: hit-images-final/artefacts/9417676.png
#  extracting: hit-images-final/artefacts/9417677.png
#  extracting: hit-images-final/artefacts/9417678.png
#  extracting: hit-images-final/artefacts/9417679.png
#  extracting: hit-images-final/artefacts/9417680.png
#  extracting: hit-images-final/artefacts/9417681.png
#  extracting: hit-images-final/artefacts/9417745.png
#  extracting: hit-images-final/artefacts/9417746.png
#  extracting: hit-images-final/artefacts/9417747.png
#  extracting: hit-images-final/artefacts/9417748.png
#  extracting: hit-images-final/artefacts/9417749.png
#  extracting: hit-images-final/artefacts/9417751.png
#  extracting: hit-images-final/artefacts/9417752.png
#  extracting: hit-images-final/artefacts/9417753.png
#  extracting: hit-images-final/artefacts/9417754.png
#  extracting: hit-images-final/artefacts/9417757.png
#  extracting: hit-images-final/artefacts/9417758.png
#  extracting: hit-images-final/artefacts/9417759.png
#  extracting: hit-images-final/artefacts/9417764.png
#  extracting: hit-images-final/artefacts/9417765.png
#  extracting: hit-images-final/artefacts/9417766.png
#  extracting: hit-images-final/artefacts/9417767.png
#  extracting: hit-images-final/artefacts/9417768.png
#  extracting: hit-images-final/artefacts/9417769.png
#  extracting: hit-images-final/artefacts/9417770.png
#  extracting: hit-images-final/artefacts/9417771.png
#  extracting: hit-images-final/artefacts/9417772.png
#  extracting: hit-images-final/artefacts/9417773.png
#  extracting: hit-images-final/artefacts/9417774.png
#  extracting: hit-images-final/artefacts/9417776.png
#  extracting: hit-images-final/artefacts/9417777.png
#  extracting: hit-images-final/artefacts/9417778.png
#  extracting: hit-images-final/artefacts/9417779.png
#  extracting: hit-images-final/artefacts/9417780.png
#  extracting: hit-images-final/artefacts/9417781.png
#  extracting: hit-images-final/artefacts/9417782.png
#  extracting: hit-images-final/artefacts/9417783.png
#  extracting: hit-images-final/artefacts/9417830.png
#  extracting: hit-images-final/artefacts/9417831.png
#  extracting: hit-images-final/artefacts/9417832.png
#  extracting: hit-images-final/artefacts/9417833.png
#  extracting: hit-images-final/artefacts/9417834.png
#  extracting: hit-images-final/artefacts/9417835.png
#  extracting: hit-images-final/artefacts/9417836.png
#  extracting: hit-images-final/artefacts/9417837.png
#  extracting: hit-images-final/artefacts/9417838.png
#  extracting: hit-images-final/artefacts/9417839.png
#  extracting: hit-images-final/artefacts/9417840.png
#  extracting: hit-images-final/artefacts/9417841.png
#  extracting: hit-images-final/artefacts/9417850.png
#  extracting: hit-images-final/artefacts/9417851.png
#  extracting: hit-images-final/artefacts/9417852.png
#  extracting: hit-images-final/artefacts/9417853.png
#  extracting: hit-images-final/artefacts/9417854.png
#  extracting: hit-images-final/artefacts/9417876.png
#  extracting: hit-images-final/artefacts/9417879.png
#  extracting: hit-images-final/artefacts/9417880.png
#  extracting: hit-images-final/artefacts/9417881.png
#  extracting: hit-images-final/artefacts/9417882.png
#  extracting: hit-images-final/artefacts/9417883.png
#  extracting: hit-images-final/artefacts/9417884.png
#  extracting: hit-images-final/artefacts/9417885.png
#  extracting: hit-images-final/artefacts/9417886.png
#  extracting: hit-images-final/artefacts/9417887.png
#  extracting: hit-images-final/artefacts/9418712.png
#  extracting: hit-images-final/artefacts/9418990.png
#  extracting: hit-images-final/artefacts/9419433.png
#  extracting: hit-images-final/artefacts/9419870.png
#  extracting: hit-images-final/artefacts/9420346.png
#  extracting: hit-images-final/artefacts/9420581.png
#  extracting: hit-images-final/artefacts/9421198.png
#  extracting: hit-images-final/artefacts/9421296.png
#  extracting: hit-images-final/artefacts/9421309.png
#  extracting: hit-images-final/artefacts/9421310.png
#  extracting: hit-images-final/artefacts/9421323.png
#  extracting: hit-images-final/artefacts/9421325.png
#  extracting: hit-images-final/artefacts/9421327.png
#  extracting: hit-images-final/artefacts/9421391.png
#  extracting: hit-images-final/artefacts/9421396.png
#  extracting: hit-images-final/artefacts/9421400.png
#  extracting: hit-images-final/artefacts/9421405.png
#  extracting: hit-images-final/artefacts/9421407.png
#  extracting: hit-images-final/artefacts/9421410.png
#  extracting: hit-images-final/artefacts/9421411.png
#  extracting: hit-images-final/artefacts/9421413.png
#  extracting: hit-images-final/artefacts/9421465.png
#  extracting: hit-images-final/artefacts/9421603.png
#  extracting: hit-images-final/artefacts/9421609.png
#  extracting: hit-images-final/artefacts/9421637.png
#  extracting: hit-images-final/artefacts/9421651.png
#  extracting: hit-images-final/artefacts/9421673.png
#  extracting: hit-images-final/artefacts/9421681.png
#  extracting: hit-images-final/artefacts/9421682.png
#  extracting: hit-images-final/artefacts/9422815.png
#  extracting: hit-images-final/artefacts/9423112.png
#  extracting: hit-images-final/artefacts/9423113.png
#  extracting: hit-images-final/artefacts/9423114.png
#  extracting: hit-images-final/artefacts/9423115.png
#  extracting: hit-images-final/artefacts/9423116.png
#  extracting: hit-images-final/artefacts/9423117.png
#  extracting: hit-images-final/artefacts/9423118.png
#  extracting: hit-images-final/artefacts/9423119.png
#  extracting: hit-images-final/artefacts/9423120.png
#  extracting: hit-images-final/artefacts/9423121.png
#  extracting: hit-images-final/artefacts/9423122.png
#  extracting: hit-images-final/artefacts/9423127.png
#  extracting: hit-images-final/artefacts/9423138.png
#  extracting: hit-images-final/artefacts/9423139.png
#  extracting: hit-images-final/artefacts/9423179.png
#  extracting: hit-images-final/artefacts/9423211.png
#  extracting: hit-images-final/artefacts/9423262.png
#  extracting: hit-images-final/artefacts/9423263.png
#  extracting: hit-images-final/artefacts/9423265.png
#  extracting: hit-images-final/artefacts/9423266.png
#  extracting: hit-images-final/artefacts/9423267.png
#  extracting: hit-images-final/artefacts/9423268.png
#  extracting: hit-images-final/artefacts/9423269.png
# ...
#  extracting: hit-images-final/hits_votes_4_Worms/17556783.png
#  extracting: hit-images-final/hits_votes_4_Worms/17558460.png
#  extracting: hit-images-final/hits_votes_4_Worms/17575675.png
#  extracting: hit-images-final/hits_votes_4_Worms/17578557.png
#  extracting: hit-images-final/hits_votes_4_Worms/17584816.png
#  extracting: hit-images-final/hits_votes_4_Worms/17615514.png
#  extracting: hit-images-final/hits_votes_4_Worms/17622408.png
#  extracting: hit-images-final/hits_votes_4_Worms/17627678.png
#  extracting: hit-images-final/hits_votes_4_Worms/17635291.png
#  extracting: hit-images-final/hits_votes_4_Worms/17638435.png
#  extracting: hit-images-final/hits_votes_4_Worms/17644817.png
#  extracting: hit-images-final/hits_votes_4_Worms/17644956.png
#  extracting: hit-images-final/hits_votes_4_Worms/17669176.png
#  extracting: hit-images-final/hits_votes_4_Worms/17670622.png
#  extracting: hit-images-final/hits_votes_4_Worms/17672752.png
#  extracting: hit-images-final/hits_votes_4_Worms/17675948.png
#  extracting: hit-images-final/hits_votes_4_Worms/17676106.png
#  extracting: hit-images-final/hits_votes_4_Worms/17676367.png
#  extracting: hit-images-final/hits_votes_4_Worms/17681024.png
#  extracting: hit-images-final/hits_votes_4_Worms/17694534.png
#  extracting: hit-images-final/hits_votes_4_Worms/17700101.png
#  extracting: hit-images-final/hits_votes_4_Worms/17703096.png
#  extracting: hit-images-final/hits_votes_4_Worms/17705278.png
#  extracting: hit-images-final/hits_votes_4_Worms/17706713.png
#  extracting: hit-images-final/hits_votes_4_Worms/17711553.png
#  extracting: hit-images-final/hits_votes_4_Worms/17715327.png
#  extracting: hit-images-final/hits_votes_4_Worms/17717661.png
#  extracting: hit-images-final/hits_votes_4_Worms/17718369.png
#  extracting: hit-images-final/hits_votes_4_Worms/17718519.png
#  extracting: hit-images-final/hits_votes_4_Worms/17719333.png
#  extracting: hit-images-final/hits_votes_4_Worms/17719654.png
#  extracting: hit-images-final/hits_votes_4_Worms/17726663.png
#  extracting: hit-images-final/hits_votes_4_Worms/17739452.png
#  extracting: hit-images-final/hits_votes_4_Worms/17752628.png
#  extracting: hit-images-final/hits_votes_4_Worms/17765754.png
#  extracting: hit-images-final/hits_votes_4_Worms/17768470.png
#  extracting: hit-images-final/hits_votes_4_Worms/17769387.png
#  extracting: hit-images-final/hits_votes_4_Worms/17771578.png
#  extracting: hit-images-final/hits_votes_4_Worms/17793014.png
#  extracting: hit-images-final/hits_votes_4_Worms/17806823.png
#  extracting: hit-images-final/hits_votes_4_Worms/17819247.png
#  extracting: hit-images-final/hits_votes_4_Worms/17861029.png
#  extracting: hit-images-final/hits_votes_4_Worms/17863297.png
#  extracting: hit-images-final/hits_votes_4_Worms/17899241.png
#  extracting: hit-images-final/hits_votes_4_Worms/17899710.png
#  extracting: hit-images-final/hits_votes_4_Worms/17901609.png
#  extracting: hit-images-final/hits_votes_4_Worms/17904159.png
#  extracting: hit-images-final/hits_votes_4_Worms/17906547.png
#  extracting: hit-images-final/hits_votes_4_Worms/17907482.png
#  extracting: hit-images-final/hits_votes_4_Worms/17920202.png
#  extracting: hit-images-final/hits_votes_4_Worms/17921082.png
#  extracting: hit-images-final/hits_votes_4_Worms/17922954.png
#  extracting: hit-images-final/hits_votes_4_Worms/17924451.png
#  extracting: hit-images-final/hits_votes_4_Worms/17932679.png
#  extracting: hit-images-final/hits_votes_4_Worms/17933558.png
#  extracting: hit-images-final/hits_votes_4_Worms/17944353.png
#  extracting: hit-images-final/hits_votes_4_Worms/17954720.png
#  extracting: hit-images-final/hits_votes_4_Worms/17972135.png
#  extracting: hit-images-final/hits_votes_4_Worms/17980882.png
#  extracting: hit-images-final/hits_votes_4_Worms/17992247.png
#  extracting: hit-images-final/hits_votes_4_Worms/17995206.png
#  extracting: hit-images-final/hits_votes_4_Worms/17996645.png
#  extracting: hit-images-final/hits_votes_4_Worms/17998165.png
#  extracting: hit-images-final/hits_votes_4_Worms/17999234.png
#  extracting: hit-images-final/hits_votes_4_Worms/18002095.png
#  extracting: hit-images-final/hits_votes_4_Worms/18019856.png
#  extracting: hit-images-final/hits_votes_4_Worms/18020217.png
#  extracting: hit-images-final/hits_votes_4_Worms/18022959.png
#  extracting: hit-images-final/hits_votes_4_Worms/18023326.png
#  extracting: hit-images-final/hits_votes_4_Worms/18023400.png
#  extracting: hit-images-final/hits_votes_4_Worms/18049287.png
#  extracting: hit-images-final/hits_votes_4_Worms/18049937.png
#  extracting: hit-images-final/hits_votes_4_Worms/18198296.png
#  extracting: hit-images-final/hits_votes_4_Worms/18204611.png
#  extracting: hit-images-final/hits_votes_4_Worms/18223628.png
#  extracting: hit-images-final/hits_votes_4_Worms/18229596.png
#  extracting: hit-images-final/hits_votes_4_Worms/18233826.png
#  extracting: hit-images-final/hits_votes_4_Worms/18234673.png
#  extracting: hit-images-final/hits_votes_4_Worms/18250739.png
#  extracting: hit-images-final/hits_votes_4_Worms/18250807.png
#  extracting: hit-images-final/hits_votes_4_Worms/18262450.png
#  extracting: hit-images-final/hits_votes_4_Worms/18266167.png
#  extracting: hit-images-final/hits_votes_4_Worms/18266266.png
#  extracting: hit-images-final/hits_votes_4_Worms/18268907.png
#  extracting: hit-images-final/hits_votes_4_Worms/18270574.png
#  extracting: hit-images-final/hits_votes_4_Worms/18283220.png
#  extracting: hit-images-final/hits_votes_4_Worms/18286072.png
#  extracting: hit-images-final/hits_votes_4_Worms/18286101.png
#  extracting: hit-images-final/hits_votes_4_Worms/18311250.png
#  extracting: hit-images-final/hits_votes_4_Worms/18330363.png
#  extracting: hit-images-final/hits_votes_4_Worms/18339915.png
#  extracting: hit-images-final/hits_votes_4_Worms/18340185.png
#  extracting: hit-images-final/hits_votes_4_Worms/18346433.png
#  extracting: hit-images-final/hits_votes_4_Worms/18346493.png
#  extracting: hit-images-final/hits_votes_4_Worms/18346594.png
#  extracting: hit-images-final/hits_votes_4_Worms/18347929.png
#  extracting: hit-images-final/hits_votes_4_Worms/18347954.png
#  extracting: hit-images-final/hits_votes_4_Worms/18349704.png
#  extracting: hit-images-final/hits_votes_4_Worms/18353548.png
#  extracting: hit-images-final/hits_votes_4_Worms/18353998.png
#  extracting: hit-images-final/hits_votes_4_Worms/18354464.png
#  extracting: hit-images-final/hits_votes_4_Worms/18364583.png
#  extracting: hit-images-final/hits_votes_4_Worms/18387853.png
#  extracting: hit-images-final/hits_votes_4_Worms/18390195.png
#  extracting: hit-images-final/hits_votes_4_Worms/18390609.png
#  extracting: hit-images-final/hits_votes_4_Worms/18401019.png
#  extracting: hit-images-final/hits_votes_4_Worms/18403141.png
#  extracting: hit-images-final/hits_votes_4_Worms/18404187.png
#  extracting: hit-images-final/hits_votes_4_Worms/18413020.png
#  extracting: hit-images-final/hits_votes_4_Worms/18413822.png
#  extracting: hit-images-final/hits_votes_4_Worms/4586587.png
#  extracting: hit-images-final/hits_votes_4_Worms/4614793.png
#  extracting: hit-images-final/hits_votes_4_Worms/4636757.png
#  extracting: hit-images-final/hits_votes_4_Worms/4658948.png
#  extracting: hit-images-final/hits_votes_4_Worms/4715376.png
#  extracting: hit-images-final/hits_votes_4_Worms/4718585.png
#  extracting: hit-images-final/hits_votes_4_Worms/4757824.png
#  extracting: hit-images-final/hits_votes_4_Worms/4847648.png
#  extracting: hit-images-final/hits_votes_4_Worms/4848789.png
#  extracting: hit-images-final/hits_votes_4_Worms/4849820.png
#  extracting: hit-images-final/hits_votes_4_Worms/4893038.png
#  extracting: hit-images-final/hits_votes_4_Worms/4894842.png
#  extracting: hit-images-final/hits_votes_4_Worms/4899178.png
#  extracting: hit-images-final/hits_votes_4_Worms/4899235.png
#  extracting: hit-images-final/hits_votes_4_Worms/4902651.png
#  extracting: hit-images-final/hits_votes_4_Worms/4913621.png
#  extracting: hit-images-final/hits_votes_4_Worms/4920311.png
#  extracting: hit-images-final/hits_votes_4_Worms/4949081.png
#  extracting: hit-images-final/hits_votes_4_Worms/4983124.png
#  extracting: hit-images-final/hits_votes_4_Worms/4986830.png
#  extracting: hit-images-final/hits_votes_4_Worms/4987786.png
#  extracting: hit-images-final/hits_votes_4_Worms/5010683.png
#  extracting: hit-images-final/hits_votes_4_Worms/5019964.png
#  extracting: hit-images-final/hits_votes_4_Worms/5020578.png
#  extracting: hit-images-final/hits_votes_4_Worms/5025696.png
#  extracting: hit-images-final/hits_votes_4_Worms/5027961.png
#  extracting: hit-images-final/hits_votes_4_Worms/5030457.png
#  extracting: hit-images-final/hits_votes_4_Worms/5040660.png
#  extracting: hit-images-final/hits_votes_4_Worms/5043553.png
#  extracting: hit-images-final/hits_votes_4_Worms/5073796.png
#  extracting: hit-images-final/hits_votes_4_Worms/5099134.png
#  extracting: hit-images-final/hits_votes_4_Worms/5100449.png
#  extracting: hit-images-final/hits_votes_4_Worms/5103006.png
#  extracting: hit-images-final/hits_votes_4_Worms/5107322.png
#  extracting: hit-images-final/hits_votes_4_Worms/5115270.png
#  extracting: hit-images-final/hits_votes_4_Worms/5134849.png
#  extracting: hit-images-final/hits_votes_4_Worms/5154754.png
#  extracting: hit-images-final/hits_votes_4_Worms/5189928.png
#  extracting: hit-images-final/hits_votes_4_Worms/5199900.png
#  extracting: hit-images-final/hits_votes_4_Worms/5206323.png
#  extracting: hit-images-final/hits_votes_4_Worms/5206345.png
#  extracting: hit-images-final/hits_votes_4_Worms/5206671.png
#  extracting: hit-images-final/hits_votes_4_Worms/5224390.png
#  extracting: hit-images-final/hits_votes_4_Worms/5247485.png
#  extracting: hit-images-final/hits_votes_4_Worms/5262983.png
#  extracting: hit-images-final/hits_votes_4_Worms/5277172.png
#  extracting: hit-images-final/hits_votes_4_Worms/5302946.png
#  extracting: hit-images-final/hits_votes_4_Worms/5304078.png
#  extracting: hit-images-final/hits_votes_4_Worms/5309424.png
#  extracting: hit-images-final/hits_votes_4_Worms/5325114.png
#  extracting: hit-images-final/hits_votes_4_Worms/5359397.png
#  extracting: hit-images-final/hits_votes_4_Worms/5376213.png
#  extracting: hit-images-final/hits_votes_4_Worms/5383752.png
#  extracting: hit-images-final/hits_votes_4_Worms/5392310.png
#  extracting: hit-images-final/hits_votes_4_Worms/5455660.png
#  extracting: hit-images-final/hits_votes_4_Worms/5468291.png
#  extracting: hit-images-final/hits_votes_4_Worms/5713771.png
#  extracting: hit-images-final/hits_votes_4_Worms/5874339.png
#  extracting: hit-images-final/hits_votes_4_Worms/5917209.png
#  extracting: hit-images-final/hits_votes_4_Worms/5927832.png
#  extracting: hit-images-final/hits_votes_4_Worms/5958693.png
#  extracting: hit-images-final/hits_votes_4_Worms/6026050.png
#  extracting: hit-images-final/hits_votes_4_Worms/6031453.png
#  extracting: hit-images-final/hits_votes_4_Worms/6161579.png
#  extracting: hit-images-final/hits_votes_4_Worms/6162187.png
#  extracting: hit-images-final/hits_votes_4_Worms/6162711.png
#  extracting: hit-images-final/hits_votes_4_Worms/6162722.png
#  extracting: hit-images-final/hits_votes_4_Worms/6162838.png
#  extracting: hit-images-final/hits_votes_4_Worms/6216882.png
#  extracting: hit-images-final/hits_votes_4_Worms/6225022.png
#  extracting: hit-images-final/hits_votes_4_Worms/6359947.png
#  extracting: hit-images-final/hits_votes_4_Worms/6379428.png
#  extracting: hit-images-final/hits_votes_4_Worms/6474452.png
#  extracting: hit-images-final/hits_votes_4_Worms/6500344.png
#  extracting: hit-images-final/hits_votes_4_Worms/6514746.png
#  extracting: hit-images-final/hits_votes_4_Worms/6665015.png
#  extracting: hit-images-final/hits_votes_4_Worms/6699230.png
#  extracting: hit-images-final/hits_votes_4_Worms/6700200.png
#  extracting: hit-images-final/hits_votes_4_Worms/6730541.png
#  extracting: hit-images-final/hits_votes_4_Worms/6774416.png
#  extracting: hit-images-final/hits_votes_4_Worms/6774607.png
#  extracting: hit-images-final/hits_votes_4_Worms/6789455.png
#  extracting: hit-images-final/hits_votes_4_Worms/6793300.png
#  extracting: hit-images-final/hits_votes_4_Worms/6813098.png
#  extracting: hit-images-final/hits_votes_4_Worms/6862821.png
#  extracting: hit-images-final/hits_votes_4_Worms/6873164.png
#  extracting: hit-images-final/hits_votes_4_Worms/6894412.png
#  extracting: hit-images-final/hits_votes_4_Worms/6908292.png
#  extracting: hit-images-final/hits_votes_4_Worms/6932719.png
#  extracting: hit-images-final/hits_votes_4_Worms/6941014.png
#  extracting: hit-images-final/hits_votes_4_Worms/6996957.png
#  extracting: hit-images-final/hits_votes_4_Worms/7051751.png
#  extracting: hit-images-final/hits_votes_4_Worms/7059498.png
#  extracting: hit-images-final/hits_votes_4_Worms/7092535.png
#  extracting: hit-images-final/hits_votes_4_Worms/7097636.png
#  extracting: hit-images-final/hits_votes_4_Worms/7126384.png
#  extracting: hit-images-final/hits_votes_4_Worms/7148947.png
#  extracting: hit-images-final/hits_votes_4_Worms/7258371.png
#  extracting: hit-images-final/hits_votes_4_Worms/7347958.png
#  extracting: hit-images-final/hits_votes_4_Worms/7373740.png
#  extracting: hit-images-final/hits_votes_4_Worms/7425840.png
#  extracting: hit-images-final/hits_votes_4_Worms/7469819.png
#  extracting: hit-images-final/hits_votes_4_Worms/7470695.png
#  extracting: hit-images-final/hits_votes_4_Worms/7471837.png
#  extracting: hit-images-final/hits_votes_4_Worms/7495229.png
#  extracting: hit-images-final/hits_votes_4_Worms/7496652.png
#  extracting: hit-images-final/hits_votes_4_Worms/7497699.png
#  extracting: hit-images-final/hits_votes_4_Worms/7501168.png
#  extracting: hit-images-final/hits_votes_4_Worms/7573913.png
#  extracting: hit-images-final/hits_votes_4_Worms/7603097.png
#  extracting: hit-images-final/hits_votes_4_Worms/7608810.png
#  extracting: hit-images-final/hits_votes_4_Worms/7612303.png
#  extracting: hit-images-final/hits_votes_4_Worms/7626075.png
#  extracting: hit-images-final/hits_votes_4_Worms/7643443.png
#  extracting: hit-images-final/hits_votes_4_Worms/7951242.png
#  extracting: hit-images-final/hits_votes_4_Worms/8033249.png
#  extracting: hit-images-final/hits_votes_4_Worms/8060193.png
#  extracting: hit-images-final/hits_votes_4_Worms/8142070.png
#  extracting: hit-images-final/hits_votes_4_Worms/8148990.png
#  extracting: hit-images-final/hits_votes_4_Worms/8459817.png
#  extracting: hit-images-final/hits_votes_4_Worms/8459821.png
#  extracting: hit-images-final/hits_votes_4_Worms/8461658.png
#  extracting: hit-images-final/hits_votes_4_Worms/8464174.png
#  extracting: hit-images-final/hits_votes_4_Worms/8482991.png
#  extracting: hit-images-final/hits_votes_4_Worms/9124194.png
#  extracting: hit-images-final/hits_votes_4_Worms/9127404.png
#  extracting: hit-images-final/hits_votes_4_Worms/9129139.png
#  extracting: hit-images-final/hits_votes_4_Worms/9129173.png
#  extracting: hit-images-final/hits_votes_4_Worms/9140411.png
#  extracting: hit-images-final/hits_votes_4_Worms/9185890.png
#  extracting: hit-images-final/hits_votes_4_Worms/9216526.png
#  extracting: hit-images-final/hits_votes_4_Worms/9217027.png
#  extracting: hit-images-final/hits_votes_4_Worms/9235722.png
#  extracting: hit-images-final/hits_votes_4_Worms/9284922.png
#  extracting: hit-images-final/hits_votes_4_Worms/9545280.png
# Collecting mahotas
#   Downloading https://files.pythonhosted.org/packages/19/ad/553b246b0a35dccc3ed58dc8889a67124bf5ab858e9c6b7255d56086e70c/mahotas-1.4.11-cp37-cp37m-manylinux2010_x86_64.whl (5.7MB)
#      |████████████████████████████████| 5.7MB 19.4MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mahotas) (1.19.5)
# Installing collected packages: mahotas
# Successfully installed mahotas-1.4.11

# %%
def loadData(path, verbose=True):

  import cv2
  import glob

  dots = []
  lines = []
  worms = []
  artefacts = []

  for img in glob.glob(path+"hits_votes_4_Dots/*.png"):
      n = cv2.imread(img)
      dots.append(n)
  target_dots = [0 for _ in dots]

  for img in glob.glob(path+"hits_votes_4_Lines/*.png"):
      n = cv2.imread(img)
      lines.append(n)
  target_lines = [1 for _ in lines]

  for img in glob.glob(path+"hits_votes_4_Worms/*.png"):
      n = cv2.imread(img)
      worms.append(n)
  target_worms = [2 for _ in worms]

  for img in glob.glob(path+"artefacts/*.png"):
      n = cv2.imread(img)
      artefacts.append(n)
  target_artefacts = [3 for _ in artefacts]

  images=dots+lines+worms+artefacts

  target_signals_binary = [0 for _ in (dots+lines+worms)]
  target_artefacts_binary = [1 for _ in artefacts]

  targets=target_signals_binary+target_artefacts_binary

  if verbose:
    print(len(images),len(targets))
    print(images[0].shape)
    print(len(dots), len(lines), len(worms), len(artefacts))


  return (images, targets)

# %%
# path="/content/drive/MyDrive/Colab Notebooks/hit-images/"
path="hit-images-final/"

images, targets = loadData(path)
# Out:
# 2354 2354
# (60, 60, 3)
# 535 393 304 1122

# %%
def preprocessData(data, wavelets=(2,), verbose=True):

  import mahotas
  import numpy as np

  print(wavelets)

  images, targets = data

  features = []
  bl_images = []
  th_images = []

  for img in images:

    img = img.astype('int32')

    blackwhite=img[:,:,0]+img[:,:,1]+img[:,:,2]
    bl_images.append(blackwhite.copy())

    threshold = blackwhite.mean() + blackwhite.std() * 5
    threshold = threshold if threshold < 100 else 100  

    mask = np.where(blackwhite > threshold, 1, 0)
    blackwhite = blackwhite * mask

    th_images.append(blackwhite.copy())


    # Transform using Dx Wavelets to obtain transformed images

    layers = {
      'raw':img.reshape(60,60,3),         
      0: blackwhite.reshape(60,60,1),        
      2: mahotas.daubechies(blackwhite,'D2').reshape(60,60,1),
      4: mahotas.daubechies(blackwhite,'D4').reshape(60,60,1),
      6: mahotas.daubechies(blackwhite,'D6').reshape(60,60,1),
      8: mahotas.daubechies(blackwhite,'D8').reshape(60,60,1),
      10: mahotas.daubechies(blackwhite,'D10').reshape(60,60,1),
      12: mahotas.daubechies(blackwhite,'D12').reshape(60,60,1),
      14: mahotas.daubechies(blackwhite,'D14').reshape(60,60,1),
      16: mahotas.daubechies(blackwhite,'D16').reshape(60,60,1),
      18: mahotas.daubechies(blackwhite,'D18').reshape(60,60,1),
      20: mahotas.daubechies(blackwhite,'D20').reshape(60,60,1)
    }

    # tt = np.concatenate((t02, t04, t06, t08), axis=2)
    out = np.concatenate(tuple(map(layers.__getitem__, wavelets)), axis=2)

    features.append(out)

  feature_array, label_array = np.array(features), np.array(targets)

  if verbose:
    print(feature_array.shape)
    print(label_array.shape)

  return (feature_array, label_array, th_images, bl_images)

# %%
feature_array, label_array, th, bl = preprocessData(data=(images, targets), wavelets=(20,))
# Out:
# (20,)
# (2354, 60, 60, 1)
# (2354,)

# %%
import tensorflow as tf
import time
begin = time.time()
print(f"TensorFlow version: {tf.__version__}")
#import keras (high level API) wiht tensorflow as backend
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint

def build_cnn_model(activation, input_shape, verbose=True):
    model = Sequential()
    
    # 2 Convolution layer with Max polling
    model.add(Conv2D(32, 5, activation = activation, padding = 'same', input_shape = input_shape))
    model.add(MaxPooling2D(pool_size = (2,2)))
    # model.add(Dropout(0.2))
    model.add(Conv2D(64, 5, activation = activation, padding = 'same', kernel_initializer = "he_normal"))
    model.add(MaxPooling2D(pool_size = (2,2)))  
    # model.add(Dropout(0.2))
    model.add(Conv2D(128, 5, activation = activation, padding = 'same', kernel_initializer = "he_normal"))
    model.add(MaxPooling2D(pool_size = (2,2)))    
    # model.add(Dropout(0.2))
    model.add(Conv2D(128, 5, activation = activation, padding = 'same', kernel_initializer = "he_normal"))
    model.add(MaxPooling2D(pool_size = (2,2)))        
    model.add(Flatten())
    
    # 3 Full connected layer
    model.add(Dense(300, activation = activation, kernel_initializer = "he_normal", 
                    kernel_regularizer=tf.keras.regularizers.l1(0.01),
                    activity_regularizer=tf.keras.regularizers.l2(0.01)))
    model.add(Dense(50, activation = activation, kernel_initializer = "he_normal", 
                    kernel_regularizer=tf.keras.regularizers.l1(0.01),
                    activity_regularizer=tf.keras.regularizers.l2(0.01)))
    model.add(Dense(2, activation = 'softmax')) # 6 classes
    
    # summarize the model
    if verbose:
      print(model.summary())
    return model

def compile_and_fit_model(model, X_train, y_train, X_test, y_test, batch_size, n_epochs, verbose=True):

    # compile the model
    model.compile(
        # optimizer=tf.keras.optimizers.Adam(),
        optimizer=tf.keras.optimizers.RMSprop(),
        loss='categorical_crossentropy',
        metrics=['accuracy'])

    model.save('init.model.h5')



    # define callbacks
    callbacks = [ModelCheckpoint(filepath='best_model.h5', monitor='val_accuracy', save_best_only=True)]
    
    # fit the model
    history = model.fit(x=X_train,
                        y=y_train,
                        batch_size=batch_size,
                        epochs=n_epochs,
                        verbose=verbose,
                        callbacks=callbacks,
                        validation_data=(X_test, y_test))
    
    return model, history
# Out:
# TensorFlow version: 2.5.0

# %%
from sklearn.model_selection import train_test_split
X_std = feature_array
y = label_array
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=0)

# X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], X_train.shape[3])
# X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], X_test.shape[3])

from tensorflow.keras.utils import to_categorical
train_cat = to_categorical(y_train)
test_cat = to_categorical(y_test)

# shape of the input images
input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
print(input_shape, X_train.shape)

# leaky ReLU
# lrelu = tf.keras.layers.LeakyReLU(alpha=0.3)

# create cnn model
cnn_model = build_cnn_model("relu", input_shape)
# cnn_model = build_cnn_model(lrelu, input_shape)
# train cnn model
print(X_train.shape, 'aaa')
trained_cnn_model, cnn_history = compile_and_fit_model(cnn_model, X_train, train_cat, X_test, test_cat, 64, 50)
# print score
loss, acc = trained_cnn_model.evaluate(X_test, test_cat)
print("acc={:.2f} loss={:.2f}".format(acc, loss))
# Out:
# (60, 60, 1) (1883, 60, 60, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 60, 60, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 128)       204928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 128)         409728
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 300)               345900
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                15050
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 1,027,804
# Trainable params: 1,027,804
# Non-trainable params: 0
# _________________________________________________________________
# None
# (1883, 60, 60, 1) aaa
# Epoch 1/50
# 30/30 [==============================] - 33s 34ms/step - loss: 702.2940 - accuracy: 0.7307 - val_loss: 102.5900 - val_accuracy: 0.7919
# Epoch 2/50
# 30/30 [==============================] - 1s 18ms/step - loss: 95.0957 - accuracy: 0.8609 - val_loss: 87.1521 - val_accuracy: 0.9299
# Epoch 3/50
# 30/30 [==============================] - 1s 17ms/step - loss: 79.9663 - accuracy: 0.8640 - val_loss: 71.6258 - val_accuracy: 0.5669
# Epoch 4/50
# 30/30 [==============================] - 1s 17ms/step - loss: 62.5569 - accuracy: 0.7233 - val_loss: 51.8153 - val_accuracy: 0.7367
# Epoch 5/50
# 30/30 [==============================] - 1s 17ms/step - loss: 41.6995 - accuracy: 0.7292 - val_loss: 30.3642 - val_accuracy: 0.9342
# Epoch 6/50
# 30/30 [==============================] - 1s 17ms/step - loss: 21.6143 - accuracy: 0.8603 - val_loss: 13.1778 - val_accuracy: 0.9639
# Epoch 7/50
# 30/30 [==============================] - 1s 17ms/step - loss: 8.6091 - accuracy: 0.9341 - val_loss: 4.9480 - val_accuracy: 0.9660
# Epoch 8/50
# 30/30 [==============================] - 1s 17ms/step - loss: 3.5774 - accuracy: 0.9655 - val_loss: 2.6608 - val_accuracy: 0.9682
# Epoch 9/50
# 30/30 [==============================] - 1s 17ms/step - loss: 2.4051 - accuracy: 0.9729 - val_loss: 2.2845 - val_accuracy: 0.9533
# Epoch 10/50
# 30/30 [==============================] - 1s 17ms/step - loss: 2.1433 - accuracy: 0.9857 - val_loss: 2.1816 - val_accuracy: 0.9618
# Epoch 11/50
# 30/30 [==============================] - 1s 17ms/step - loss: 2.0759 - accuracy: 0.9830 - val_loss: 2.1028 - val_accuracy: 0.9639
# Epoch 12/50
# 30/30 [==============================] - 1s 17ms/step - loss: 2.0394 - accuracy: 0.9883 - val_loss: 2.0823 - val_accuracy: 0.9682
# Epoch 13/50
# 30/30 [==============================] - 1s 17ms/step - loss: 2.0155 - accuracy: 0.9910 - val_loss: 2.0680 - val_accuracy: 0.9682
# Epoch 14/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9953 - accuracy: 0.9920 - val_loss: 2.0559 - val_accuracy: 0.9618
# Epoch 15/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9948 - accuracy: 0.9862 - val_loss: 2.0308 - val_accuracy: 0.9703
# Epoch 16/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9632 - accuracy: 0.9968 - val_loss: 2.0981 - val_accuracy: 0.9597
# Epoch 17/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.9653 - accuracy: 0.9915 - val_loss: 2.0372 - val_accuracy: 0.9682
# Epoch 18/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9458 - accuracy: 0.9952 - val_loss: 2.0357 - val_accuracy: 0.9639
# Epoch 19/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.9621 - accuracy: 0.9899 - val_loss: 2.0244 - val_accuracy: 0.9618
# Epoch 20/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9260 - accuracy: 0.9989 - val_loss: 2.0707 - val_accuracy: 0.9639
# Epoch 21/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.9254 - accuracy: 0.9984 - val_loss: 2.0550 - val_accuracy: 0.9639
# Epoch 22/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9244 - accuracy: 0.9936 - val_loss: 2.0352 - val_accuracy: 0.9639
# Epoch 23/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9112 - accuracy: 0.9995 - val_loss: 2.0495 - val_accuracy: 0.9639
# Epoch 24/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.9115 - accuracy: 0.9984 - val_loss: 2.0254 - val_accuracy: 0.9618
# Epoch 25/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9129 - accuracy: 0.9968 - val_loss: 2.0284 - val_accuracy: 0.9554
# Epoch 26/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8987 - accuracy: 0.9995 - val_loss: 2.0223 - val_accuracy: 0.9639
# Epoch 27/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9070 - accuracy: 0.9942 - val_loss: 2.0191 - val_accuracy: 0.9660
# Epoch 28/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8993 - accuracy: 0.9963 - val_loss: 1.9994 - val_accuracy: 0.9682
# Epoch 29/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.9030 - accuracy: 0.9936 - val_loss: 1.9915 - val_accuracy: 0.9660
# Epoch 30/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.8868 - accuracy: 1.0000 - val_loss: 1.9871 - val_accuracy: 0.9639
# Epoch 31/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8959 - accuracy: 0.9952 - val_loss: 2.0013 - val_accuracy: 0.9682
# Epoch 32/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8891 - accuracy: 0.9973 - val_loss: 1.9808 - val_accuracy: 0.9703
# Epoch 33/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8856 - accuracy: 0.9984 - val_loss: 1.9863 - val_accuracy: 0.9682
# Epoch 34/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.8816 - accuracy: 0.9989 - val_loss: 2.1386 - val_accuracy: 0.9448
# Epoch 35/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.8822 - accuracy: 0.9995 - val_loss: 1.9848 - val_accuracy: 0.9618
# Epoch 36/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8773 - accuracy: 1.0000 - val_loss: 2.0763 - val_accuracy: 0.9512
# Epoch 37/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8819 - accuracy: 0.9968 - val_loss: 2.0113 - val_accuracy: 0.9639
# Epoch 38/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8750 - accuracy: 0.9995 - val_loss: 1.9986 - val_accuracy: 0.9660
# Epoch 39/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8729 - accuracy: 1.0000 - val_loss: 1.9787 - val_accuracy: 0.9703
# Epoch 40/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.8742 - accuracy: 0.9989 - val_loss: 1.9908 - val_accuracy: 0.9639
# Epoch 41/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8782 - accuracy: 0.9963 - val_loss: 1.9735 - val_accuracy: 0.9682
# Epoch 42/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8670 - accuracy: 1.0000 - val_loss: 2.0053 - val_accuracy: 0.9639
# Epoch 43/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8820 - accuracy: 0.9952 - val_loss: 1.9888 - val_accuracy: 0.9618
# Epoch 44/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.8656 - accuracy: 1.0000 - val_loss: 2.0020 - val_accuracy: 0.9597
# Epoch 45/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.8695 - accuracy: 0.9984 - val_loss: 1.9963 - val_accuracy: 0.9618
# Epoch 46/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8636 - accuracy: 1.0000 - val_loss: 1.9944 - val_accuracy: 0.9682
# Epoch 47/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8670 - accuracy: 0.9989 - val_loss: 1.9710 - val_accuracy: 0.9660
# Epoch 48/50
# 30/30 [==============================] - 1s 17ms/step - loss: 1.8617 - accuracy: 1.0000 - val_loss: 1.9738 - val_accuracy: 0.9639
# Epoch 49/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.8604 - accuracy: 1.0000 - val_loss: 2.0094 - val_accuracy: 0.9469
# Epoch 50/50
# 30/30 [==============================] - 1s 18ms/step - loss: 1.8626 - accuracy: 0.9984 - val_loss: 2.0265 - val_accuracy: 0.9639
# 15/15 [==============================] - 0s 5ms/step - loss: 2.0265 - accuracy: 0.9639
# acc=0.96 loss=2.03

# %%
import matplotlib.pyplot as plt

acc = cnn_history.history['accuracy']
loss = cnn_history.history['loss']

val_acc = cnn_history.history['val_accuracy']
val_loss = cnn_history.history['val_loss']

epochs = range(len(acc))

plt.style.use('dark_background')
plt.figure()

plt.plot(epochs, acc, 'r', label='train accuracy')
plt.plot(epochs, val_acc, 'g', label='validation accuracy')
plt.title('Accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'r', label='train loss')
plt.plot(epochs, val_loss, 'g', label='accuracy loss')
plt.title('Loss')
plt.legend()

plt.show()

# %%
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np

def create_confusion_matrix(y_pred, y_test):    

  cm = confusion_matrix(y_test, y_pred)
  # Normalise
  cmn = 100 * cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
  fig, ax = plt.subplots(figsize=(5,5))
  target_names = [0, 1]
  sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=target_names, yticklabels=target_names)
  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  plt.show(block=False)    

# make predictions for test data
# y_pred = trained_cnn_model.predict_classes(X_test)
y_pred = np.argmax(trained_cnn_model.predict(X_test), axis=1)
# determine the total accuracy 
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# print score
loss, acc = trained_cnn_model.evaluate(X_test, test_cat)
print("acc={:.2f} loss={:.2f}".format(acc, loss))

create_confusion_matrix(y_pred, y_test)
# Out:
# Accuracy: 96.39%
# 15/15 [==============================] - 0s 6ms/step - loss: 2.0265 - accuracy: 0.9639
# acc=0.96 loss=2.03

# %%
trained_cnn_model.load_weights('best_model.h5')

test_loss, test_acc = trained_cnn_model.evaluate(X_test, test_cat)
print('test_loss', test_loss, 'test_acc', test_acc)

trained_cnn_model.summary()
# Out:
# 15/15 [==============================] - 0s 6ms/step - loss: 2.0308 - accuracy: 0.9703
# test_loss 2.0308053493499756 test_acc 0.9702759981155396
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 60, 60, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 128)       204928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 128)         409728
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 300)               345900
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                15050
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 1,027,804
# Trainable params: 1,027,804
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions for test data
# y_pred = trained_cnn_model.predict_classes(X_test)
y_pred = np.argmax(trained_cnn_model.predict(X_test), axis=1)
# determine the total accuracy 
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# print score
loss, acc = trained_cnn_model.evaluate(X_test, test_cat)
print("acc={:.2f} loss={:.2f}".format(acc, loss))

create_confusion_matrix(y_pred, y_test)
# Out:
# Accuracy: 97.03%
# 15/15 [==============================] - 0s 6ms/step - loss: 2.0308 - accuracy: 0.9703
# acc=0.97 loss=2.03

# %%
def kf_validation(X_std, y, _clf_, rounds=1, verbose=False):
  import numpy as np
  from sklearn.model_selection import KFold
  from sklearn import svm
  from sklearn.metrics import accuracy_score
  from sklearn.metrics import confusion_matrix
  import matplotlib.pyplot as plt
  import tensorflow as tf
  from tensorflow import keras
  from tensorflow.keras.utils import to_categorical
  from functools import reduce

  scores = []
  CM = np.zeros_like(np.eye(4))
  cm_seq = []

  for _ in range(rounds):

    kf = KFold(n_splits=5, shuffle=True)
    kf.get_n_splits(X_std)

    for train_index, test_index in kf.split(X_std):
      # print("TRAIN:", train_index, "TEST:", test_index)
      X_train, X_test = X_std[train_index], X_std[test_index]
      y_train, y_test = y[train_index], y[test_index]

      # C = 1.0
      # clf = _clf_
      # clf = keras.models.load_model(_clf_)

      # keras.backend.clear_session()
      # clf.fit(X_train, to_categorical(y_train), batch_size=64, epochs=50, verbose=False)

      cnn_model = build_cnn_model("relu", input_shape, verbose=False)
      clf, cnn_history = compile_and_fit_model(cnn_model, X_train, to_categorical(y_train), 
                                               X_test, to_categorical(y_test), 
                                               64, 50, 
                                               verbose=False)

      clf.load_weights('best_model.h5')

      y_pred = np.argmax(clf.predict(X_test), axis=1)
      score = 100*accuracy_score(y_test, y_pred)
      scores.append(score)
      print('Accyracy: {:.2f}%'.format(score))  
      loss, acc = clf.evaluate(X_test, to_categorical(y_test))
      # print("acc={:.2f} loss={:.2f}".format(acc, loss))

      cm = confusion_matrix(y_test, y_pred)
      # print(cm)
      # CM = CM + cm
      cm_seq.append(cm.copy())

  # print('\nDokładność uśredniona: {:.2f}%'.format(sum(scores)/len(scores)))  

  from sklearn.metrics import confusion_matrix
  import seaborn as sns

  # cm = CM
  cm = reduce(np.add, cm_seq)
  # print(cm)
  
  # cm = CM
  # Normalise
  cmn = 100 * cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

  if verbose==True:
    fig, ax = plt.subplots(figsize=(6,5))
    target_names = [0, 1]
    sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=target_names, yticklabels=target_names)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show(block=False)

    print()

  # Std devs
  cm_seq = np.array(cm_seq)
  # cmn_std = 100 * np.divide(cm_seq.std(axis=2), cm_seq.sum(axis=2))
  cumulative = []
  for item in cm_seq:
    c_ = 100 * item.astype('float') / item.sum(axis=1)[:, np.newaxis]
    cumulative.append(c_)

  cmn_std = np.array(cumulative).std(axis=0)  

  if verbose==True:
    fig, ax = plt.subplots(figsize=(6,5))
    target_names = [0, 1]
    sns.heatmap(cmn_std, annot=True, fmt='.2f', xticklabels=target_names, yticklabels=target_names)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show(block=False)

    scores_mean = np.array(scores).mean()
    scores_std = np.array(scores).std()

  return (cmn, cmn_std, scores_mean, scores_std)

# %%
# for _ in range(5):
# cm, cm_std = kf_validation(X_std, y, trained_cnn_model, verbose=True)
cm, cm_std, acc_mean, acc_std = kf_validation(X_std, y, 'init.model.h5', rounds=30, verbose=True)

print('Average accuracy: ', acc_mean)
print('Std dev accuracy: ', acc_std)
end  = time.time()
print('#########################################################')
print("time: ",end-begin)
print('#########################################################')
# Out:
# Accyracy: 98.09%
# 15/15 [==============================] - 0s 7ms/step - loss: 1.9453 - accuracy: 0.9809
# Accyracy: 98.73%
# 15/15 [==============================] - 0s 6ms/step - loss: 1.9529 - accuracy: 0.9873
# Accyracy: 98.51%
# 15/15 [==============================] - 0s 5ms/step - loss: 1.9389 - accuracy: 0.9851
# Accyracy: 98.09%
# 15/15 [==============================] - 0s 5ms/step - loss: 1.9872 - accuracy: 0.9809
# Accyracy: 98.51%
# 15/15 [==============================] - 0s 6ms/step - loss: 2.0506 - accuracy: 0.9851
# Accyracy: 98.51%
# 15/15 [==============================] - 0s 6ms/step - loss: 1.9363 - accuracy: 0.9851
# Accyracy: 98.09%
# 15/15 [==============================] - 0s 5ms/step - loss: 1.9520 - accuracy: 0.9809
# Accyracy: 98.51%
# 15/15 [==============================] - 0s 5ms/step - loss: 1.9123 - accuracy: 0.9851
# Accyracy: 97.88%
# 15/15 [==============================] - 0s 6ms/step - loss: 1.9364 - accuracy: 0.9788
# Accyracy: 98.51%
# 15/15 [==============================] - 0s 5ms/step - loss: 1.9186 - accuracy: 0.9851
# Accyracy: 98.51%
# 15/15 [==============================] - 0s 6ms/step - loss: 1.9807 - accuracy: 0.9851
# Accyracy: 98.73%
# 15/15 [==============================] - 0s 6ms/step - loss: 1.9364 - accuracy: 0.9873
# Accyracy: 98.30%
# 15/15 [==============================] - 0s 5ms/step - loss: 1.9382 - accuracy: 0.9830
# Accyracy: 98.94%
# 15/15 [==============================] - 0s 5ms/step - loss: 1.9839 - accuracy: 0.9894
# Accyracy: 97.66%
# 15/15 [==============================] - 0s 5ms/step - loss: 1.9734 - accuracy: 0.9766
# Average accuracy:  98.37150472060353
# Std dev accuracy:  0.33547639923361566
# #########################################################
# time:  760.4437227249146
# #########################################################

# %%
print(np.round(cm,2))
print(np.round(cm_std,2))
# Out:
# [[98.48  1.52]
#  [ 1.75 98.25]]
# [[0.69 0.69]
#  [0.64 0.64]]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  print("Name:", gpu.name, "  Type:", gpu.device_type)
